# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# %store -r numeric_cols
# %store -r target
# %store -r non_numeric_cols

# %%
numeric_cols.head()
# Out:
#    employment_years  annual_income  credit_score  debt_to_income_ratio  \
# 0                 0       42963.81           672                 0.169
# 1                27       90949.60           643                 0.313
# 2                24       60941.84           748                 0.476
# 3                11       52830.38           660                 0.115
# 4                18       57200.50           654                 0.465
#
#    savings_balance  existing_loans_count  missed_payments_12m  \
# 0         35540.30                     0                    0
# 1          9760.72                     3                    0
# 2         53373.76                     2                    0
# 3         17127.76                     0                    0
# 4         32561.08                     2                    0
#
#    requested_loan_amount  age
# 0               10901.07   25
# 1               24216.29   55
# 2               29579.03   50
# 3               28667.75   40
# ...
